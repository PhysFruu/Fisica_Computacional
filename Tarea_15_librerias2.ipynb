# %% [markdown]
# # Librerias

# %%
include("herramientas.jl")
# Out:
# herramientas

# %%
?herramientas.metodo_newton
# Out:
# Para metodo_newton raphson se ingresan los valores:  (función, punto inicial, *repeticiónes [50]) *Valor opcional, [#] valores predeterminados

# %%
f(x)=x-1
herramientas.metodo_newton(f,0)
# Out:
# 1.0

# %%
?herramientas.integracion_rectangulo
# Out:
# Para las funciones de integracion_ se pide  la función (f) el intervalo de integración de (a) a (b)  el número de intervalos de dicha partición (n)
#
# ingresandose de la forma: (f,a,b,*n[100000]) *Valor opcional, [#] valores predeterminados

# %%
herramientas.integracion_rectangulo(f,0,4)
# Out:
# 4.000000000000002

# %%
herramientas.integracion_simpson(f,0,4)
# Out:
# 4.000000000000002

# %%
herramientas.integracion_trapecio(f,0,4)
# Out:
# 4.000000000000002

# %%
?herramientas.metodo_RK4
# Out:
# Resolución de ecuaciones diferenciales ordinarias. Para el método de euler, euler implicito y Runge-Kutta se encuentran dos versiones. Ambas funciones tienen paramentros de entrada: f función definida como una función con parametro de evaluación x (vector o escalar) y un tiempo. i.e. f(x,t) x0 ó xi condición inicial al tiempo inicial ti timpo inicial tf tiempo final
#
# La primera versión se da designando (n) como el número de intervalos equipartidos de tiempo que tendrá la evaluación llamandose a la función metodo_algo(f,x0,ti,tf,n)
#
# La segunda versión se da designando (h) como el tamaño del intervalo equipartido de tiempo que tendrá la evaluación llamandose a la función metodo_algoh(f,x0,ti,tf,h)
#
# ...

# %%
x0=4
ti=0
tf=5
h=.01
n=10
# Out:
# 10

# %%
using PyPlot

# %%
F(x,t)=f(x)
plot(herramientas.metodo_euler(F,0,0,1,n)[1],herramientas.metodo_euler(F,4,0,1,n)[2],label="test Euler")
plot(herramientas.metodo_eulerimp(F,0,0,1,n)[1],herramientas.metodo_eulerimp(F,4,0,1,n)[2],label="test Euler Implicito")
plot(herramientas.metodo_RK4(F,0,0,1,n)[1],herramientas.metodo_RK4(F,4,0,1,n)[2],label="test Runge-kutta")
legend()
show();
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4efa1ffa10>)

# %%
plot(herramientas.metodo_eulerh(F,0,0,1,h)[1],herramientas.metodo_eulerh(F,4,0,1,h)[2],label="test Euler")
plot(herramientas.metodo_eulerimph(F,0,0,1,h)[1],herramientas.metodo_eulerimph(F,4,0,1,h)[2],label="test Euler Implicito")
plot(herramientas.metodo_RK4h(F,0,0,1,h)[1],herramientas.metodo_RK4h(F,4,0,1,h)[2],label="test Runge-kutta")
legend()
show();
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x7f4efa22ab50>)

# %% [markdown]
# *****
# ```python
# F F M G
# ```
